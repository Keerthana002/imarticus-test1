# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
file=pd.read_csv('/content/drive/MyDrive/bank.csv',delimiter=';')

# %%
file
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
files=pd.DataFrame(file)
files
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
file.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
file.tail()
# Out:
#        age          job  marital            education default housing loan  \
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 41183  cellular   nov         fri  ...         1    999         0
# 41184  cellular   nov         fri  ...         1    999         0
# 41185  cellular   nov         fri  ...         2    999         0
# 41186  cellular   nov         fri  ...         1    999         0
# 41187  cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
file.shape
# Out:
# (41188, 21)

# %%
file.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
file=file.drop_duplicates()
file.duplicated().sum()
# Out:
# 0

# %%
file.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41176.00000  41176.000000  41176.000000  41176.000000  41176.000000
# mean      40.02380    258.315815      2.567879    962.464810      0.173013
# std       10.42068    259.305321      2.770318    186.937102      0.494964
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41176.000000    41176.000000   41176.000000  41176.000000  41176.000000
# mean       0.081922       93.575720     -40.502863      3.621293   5167.034870
# ...

# %%
file.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
num_fea = file.dtypes[file.dtypes != "object"].index
print(num_fea)
print(len(num_fea))
# Out:
# Index(['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed'],
#       dtype='object')
# 10

# %%
cat_fea =file.dtypes[file.dtypes == "object"].index
print(cat_fea)
print(len(cat_fea))
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome', 'y'],
#       dtype='object')
# 11

# %%
type(num_fea)
# Out:
# pandas.core.indexes.base.Index

# %%
sns.set(font_scale=1.2)

f = pd.melt(file, id_vars=['nr.employed'], value_vars=cat_fea)
facetobject = sns.FacetGrid(f, col="variable", col_wrap=2, sharex=False, sharey=False, size=10)
facetobject.map(sns.boxplot, "value", "nr.employed", palette="Set3")
facetobject.fig.subplots_adjust(wspace=.30, hspace=0.30)


for ax in facetobject.axes.flat: 
    plt.setp(ax.get_xticklabels(), rotation=90)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:670: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
file.hist(bins=100, figsize=(40,25),color='purple')
plt.show()

# %%
corr = file.corr()
plt.figure(figsize=(20,15))
sns.heatmap(corr,annot=True,cmap='crest')

# %%
sns.pairplot(file)

# %%
plt.figure(figsize=(10,5))
sns.countplot(file.marital)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
file.corr().style.background_gradient(cmap="afmhot")
# Out:
# <style type="text/css">
# #T_150ef_row0_col0, #T_150ef_row1_col1, #T_150ef_row2_col2, #T_150ef_row3_col3, #T_150ef_row4_col4, #T_150ef_row5_col5, #T_150ef_row6_col6, #T_150ef_row7_col7, #T_150ef_row8_col8, #T_150ef_row9_col9 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_150ef_row0_col1 {
#   background-color: #200000;
#   color: #f1f1f1;
# }
# #T_150ef_row0_col2, #T_150ef_row1_col7 {
#   background-color: #260000;
#   color: #f1f1f1;
# }
# #T_150ef_row0_col3 {
#   background-color: #b23200;
#   color: #f1f1f1;
# }
# #T_150ef_row0_col4, #T_150ef_row1_col4 {
#   background-color: #c44400;
#   color: #f1f1f1;
# }
# #T_150ef_row0_col5 {
#   background-color: #961700;
#   color: #f1f1f1;
# }
# #T_150ef_row0_col6 {
#   background-color: #560000;
#   color: #f1f1f1;
# }
# #T_150ef_row0_col7 {
#   background-color: #660000;
#   color: #f1f1f1;
# }
# #T_150ef_row0_col8, #T_150ef_row2_col4 {
#   background-color: #a22200;
#   color: #f1f1f1;
# }
# #T_150ef_row0_col9 {
# ...

# %%
from sklearn.model_selection import train_test_split
Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,Y,test_size=0.15,random_state=3)

# %%
from sklearn.preprocessing import LabelEncoder
model = LabelEncoder()
label = model.fit_transform(file['job'])
label
# Out:
# array([3, 7, 7, ..., 5, 9, 5])

# %%
from sklearn.preprocessing import LabelEncoder
model = LabelEncoder()
label = model.fit_transform(file['marital'])
label
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
from sklearn.preprocessing import LabelEncoder
model = LabelEncoder()
label = model.fit_transform(file['education'])
label
# Out:
# array([0, 3, 3, ..., 6, 5, 5])

# %%
from sklearn.preprocessing import LabelEncoder
model = LabelEncoder()
label = model.fit_transform(file['default'])
label
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
from sklearn.preprocessing import LabelEncoder
model = LabelEncoder()
label = model.fit_transform(file['loan'])
label
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.preprocessing import LabelEncoder
model = LabelEncoder()
label = model.fit_transform(file['housing'])
label
# Out:
# array([0, 0, 2, ..., 2, 0, 2])

# %%
from sklearn.preprocessing import LabelEncoder
model = LabelEncoder()
label = model.fit_transform(file['contact'])
label
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
from sklearn.preprocessing import LabelEncoder
model = LabelEncoder()
label = model.fit_transform(file['month'])
label
# Out:
# array([6, 6, 6, ..., 7, 7, 7])

# %%
from sklearn.preprocessing import LabelEncoder
model = LabelEncoder()
label = model.fit_transform(file['day_of_week'])
label
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
from sklearn.preprocessing import LabelEncoder
model = LabelEncoder()
label = model.fit_transform(file['poutcome'])
label
# Out:
# array([1, 1, 1, ..., 1, 1, 0])

# %%
from sklearn.preprocessing import LabelEncoder
model = LabelEncoder()
label = model.fit_transform(file['y'])
label
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
X=file.drop(columns=['job','marital','education','default','housing','loan','contact','month','day_of_week','poutcome','y'])

X
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0       56       261         1    999         0           1.1          93.994
# 1       57       149         1    999         0           1.1          93.994
# 2       37       226         1    999         0           1.1          93.994
# 3       40       151         1    999         0           1.1          93.994
# 4       56       307         1    999         0           1.1          93.994
# ...    ...       ...       ...    ...       ...           ...             ...
# 41183   73       334         1    999         0          -1.1          94.767
# 41184   46       383         1    999         0          -1.1          94.767
# 41185   56       189         2    999         0          -1.1          94.767
# 41186   44       442         1    999         0          -1.1          94.767
# 41187   74       239         3    999         1          -1.1          94.767
#
# ...

# %%
Y=file.y

# %%
file['y']=label
file
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()
model.fit(Xtrain,Ytrain)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
from sklearn.preprocessing import LabelEncoder
model = LabelEncoder()
label = model.fit_transform(file['job'])
label
# Out:
# array([3, 7, 7, ..., 5, 9, 5])

# %%
model=LogisticRegression()
model.fit(Xtrain,Ytrain)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
ypred=model.predict(Xtest)
model.predict_proba(Xtest)
# Out:
# array([[0.88281679, 0.11718321],
#        [0.98978634, 0.01021366],
#        [0.86751421, 0.13248579],
#        ...,
#        [0.82817851, 0.17182149],
#        [0.89497479, 0.10502521],
#        [0.9489065 , 0.0510935 ]])

# %%
y_pred=model.predict(Xtest)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
accuracy_score(Ytest,ypred)
# Out:
# 0.9106362311801846

# %%
confusion_matrix(Ytest,ypred)
# Out:
# array([[5352,  145],
#        [ 407,  273]])

# %%
print(classification_report(Ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95      5497
#            1       0.65      0.40      0.50       680
#
#     accuracy                           0.91      6177
#    macro avg       0.79      0.69      0.72      6177
# weighted avg       0.90      0.91      0.90      6177
